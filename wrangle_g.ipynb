# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
sns.color_palette("tab10")
from scipy import stats
from sklearn.model_selection import train_test_split
import os
from langdetect import detect
seed = 1349

# %%
def detect_language(text):
    try:
        return detect(text)
    except:
        return None

# %%
def acquire():
    '''
    Obtains the vanilla version of both the red and white wine dataframe
    INPUT:
    NONE
    OUTPUT:
    red = pandas dataframe with red wine data
    white = pandas dataframe with white wine data
    '''
    r = pd.read_csv('langr_raw.csv')
    python = pd.read_csv('langp_raw.csv')
    return r, python

# %%
r, python = acquire()

# %%
r
# Out:
#      Unnamed: 0                               repo language
# 0             0            ujjwalkarn/DataScienceR        R  \
# 1             1         IndrajeetPatil/ggstatsplot        R
# 2             2                easystats/easystats        R
# 3             3                 seandavi/sars2pack        R
# 4             4           markvanderloo/lumberjack        R
# ..          ...                                ...      ...
# 170         170                         leenock/ML        R
# 171         171    Phelipe-Sempreboni/data-science        R
# 172         172  fernandapilat/r-para-data-science        R
# 173         173     lcasilva/Projeto_DSA_Feedback2        R
# 174         174     lcasilva/Projeto_DSA_feedback1        R
#
#                                        readme_contents
# 0    # R Data Science Tutorials\n- This repo contai...
# 1    ---\noutput: github_document\n---\n\n  <!-- RE...
# 2    ---\noutput: github_document\n---\n\n```{r, wa...
# 3    ---\noutput: \n  - rmarkdown::github_document\...
# 4    ## Track changes in data\n[![Build Status](htt...
# ..                                                 ...
# 170                                                ��#
# 171  # Data Science\n\n---\n\n### Esse repositório ...
# 172  # R para Data Science\n\nRepositório criado pa...
# 173  # Projeto_Feedback2\nProjeto Feedback 2: Machi...
# 174  # Projeto_feedback1 (Curso Big Data Analytics ...
#
# [175 rows x 4 columns]

# %%
python
# Out:
#      Unnamed: 0                                           repo language
# 0             0                               ludwig-ai/ludwig   Python  \
# 1             1                            modin-project/modin   Python
# 2             2                               Netflix/metaflow   Python
# 3             3                            lk-geimfari/mimesis   Python
# 4             4                                  holoviz/panel   Python
# ..          ...                                            ...      ...
# 175         175                 rahulbordoloi/Machine-Learning   Python
# 176         176                           Oslandia/QDeeplandia   Python
# 177         177  arjunbhasin2013/BaselinePredictionMLFramework   Python
# 178         178              PonderaLab/datascience4economists   Python
# 179         179                           joaoariedi/etl_luigi   Python
#
#                                        readme_contents
# 0    ![Ludwig logo](https://github.com/ludwig-ai/lu...
# 1    <p align="center"><a href="https://modin.readt...
# 2    ![Metaflow_Logo_Horizontal_FullColor_Ribbon_Da...
# 3    Mimesis: The Fake Data Generator\n------------...
# 4    <a href="https://panel.holoviz.org/">\n  <pict...
# ..                                                 ...
# 175  # Machine-Learning\nContains my Glossary for M...
# 176  QGIS plugin dedicated to 2D semantic segmentat...
# 177  # Baseline Prediction Machine Learning Framewo...
# 178  # Datascience4economists\n\nFirst of all, welc...
# 179  # LUIGI and PostgreSQL ETL tests\nGet data fro...
#
# [180 rows x 4 columns]

# %%
def prepare_mvp():
    '''
    Takes in the vanilla red and white wine dataframes and returns a cleaned version that is ready 
    for exploration and further analysis
    INPUT:
    NONE
    OUTPUT:
    wines = pandas dataframe with both red and white wine prepped for exploration
    '''
    r, python = acquire()
    df = pd.concat([r, python], ignore_index = True)
    df = df.drop('Unnamed: 0', axis=1)
    df = df.drop_duplicates()
    df['readme_language'] = df['readme_contents'].apply(detect_language)
    df = df[df['readme_language'] == 'en']
    df = df.drop('readme_language', axis=1)
    return df

# %%
df = prepare_mvp()

# %%
df
# Out:
#                                               repo language
# 0                          ujjwalkarn/DataScienceR        R  \
# 1                       IndrajeetPatil/ggstatsplot        R
# 2                              easystats/easystats        R
# 3                               seandavi/sars2pack        R
# 4                         markvanderloo/lumberjack        R
# ..                                             ...      ...
# 350                 rahulbordoloi/Machine-Learning   Python
# 351                           Oslandia/QDeeplandia   Python
# 352  arjunbhasin2013/BaselinePredictionMLFramework   Python
# 353              PonderaLab/datascience4economists   Python
# 354                           joaoariedi/etl_luigi   Python
#
#                                        readme_contents
# 0    # R Data Science Tutorials\n- This repo contai...
# 1    ---\noutput: github_document\n---\n\n  <!-- RE...
# 2    ---\noutput: github_document\n---\n\n```{r, wa...
# 3    ---\noutput: \n  - rmarkdown::github_document\...
# 4    ## Track changes in data\n[![Build Status](htt...
# ..                                                 ...
# 350  # Machine-Learning\nContains my Glossary for M...
# 351  QGIS plugin dedicated to 2D semantic segmentat...
# 352  # Baseline Prediction Machine Learning Framewo...
# 353  # Datascience4economists\n\nFirst of all, welc...
# 354  # LUIGI and PostgreSQL ETL tests\nGet data fro...
#
# [291 rows x 3 columns]

# %%
df.to_csv('language_data.csv', index=False)

# %%
df
# Out:
#                                               repo language
# 0                          ujjwalkarn/DataScienceR        R  \
# 1                       IndrajeetPatil/ggstatsplot        R
# 2                              easystats/easystats        R
# 3                               seandavi/sars2pack        R
# 4                         markvanderloo/lumberjack        R
# ..                                             ...      ...
# 350                 rahulbordoloi/Machine-Learning   Python
# 351                           Oslandia/QDeeplandia   Python
# 352  arjunbhasin2013/BaselinePredictionMLFramework   Python
# 353              PonderaLab/datascience4economists   Python
# 354                           joaoariedi/etl_luigi   Python
#
#                                        readme_contents
# 0    # R Data Science Tutorials\n- This repo contai...
# 1    ---\noutput: github_document\n---\n\n  <!-- RE...
# 2    ---\noutput: github_document\n---\n\n```{r, wa...
# 3    ---\noutput: \n  - rmarkdown::github_document\...
# 4    ## Track changes in data\n[![Build Status](htt...
# ..                                                 ...
# 350  # Machine-Learning\nContains my Glossary for M...
# 351  QGIS plugin dedicated to 2D semantic segmentat...
# 352  # Baseline Prediction Machine Learning Framewo...
# 353  # Datascience4economists\n\nFirst of all, welc...
# 354  # LUIGI and PostgreSQL ETL tests\nGet data fro...
#
# [291 rows x 3 columns]
